# %% [markdown]
# # Titanic Dataset

# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('titanic.csv')

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.describe()[:4][['PassengerId',
                   'Survived']]
# Out:
#        PassengerId    Survived
# count   891.000000  891.000000
# mean    446.000000    0.392817
# std     257.353842    0.504490
# min       1.000000    0.000000

# %%
df[::5]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 5              6         0       3
# 10            11         1       3
# 15            16         1       2
# 20            21         0       2
# ..           ...       ...     ...
# 870          871         0       3
# 875          876         1       3
# 880          881         1       2
# 885          886         0       3
# 890          891         0       3
#
#                                              Name  Gender   Age  SibSp  Parch  \
# 0                         Braund, Mr. Owen Harris    male  22.0      1      0
# 5                                Moran, Mr. James    male   NaN      0      0
# 10                Sandstrom, Miss. Marguerite Rut  female   4.0      1      1
# 15               Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0      0
# 20                           Fynney, Mr. Joseph J    male  35.0      0      0
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Gender', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df[['PassengerId', 'Pclass', 'Name', 'Gender', 'Age', 'SibSp',
       'Parch', 'Ticket',  'Cabin', 'Embarked', 'Fare', 'Survived']]
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
# ...

# %%
df[2:5][['PassengerId','Survived']]
# Out:
#    PassengerId  Survived
# 2            3         1
# 3            4         1
# 4            5         0

# %%
df.loc[2:5,['Survived']]
# Out:
#    Survived
# 2         1
# 3         1
# 4         0
# 5         0

# %%
df.iloc[:5,:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Gender
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male

# %%
df.iloc[:3,:2] = 14
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0             14        14       3
# 1             14        14       1
# 2             14        14       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Gender           0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'].isna().sum()
# Out:
# 177

# %%
df.columns[df.isna().any()]
# Out:
# Index(['Age', 'Cabin', 'Embarked'], dtype='object')

# %%
df = pd.read_csv('titanic.csv')

# %%
a = df.Age.mean()
df['Age'].fillna(a,inplace=True)

# %%
df.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Gender         0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df['Cabin'] = df['Cabin'].fillna(method='bfill')

# %%
df['Cabin'].isna().sum()
# Out:
# 0

# %%
import statistics as st
df[890:890]['Cabin'] = st.mode(df['Cabin'])

# %%
st.mode(df['Cabin'])
# Out:
# 'C78'

# %%
df['Cabin'] = df['Cabin'].fillna(method='ffill')

# %%
df.Embarked
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
df['Embarked'] = df['Embarked'].fillna(st.mode(df['Embarked']))

# %%
df.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Gender         0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df.loc[df['Age']<50 ].index
# Out:
# Int64Index([  0,   1,   2,   3,   4,   5,   7,   8,   9,  10,
#             ...
#             881, 882, 883, 884, 885, 886, 887, 888, 889, 890],
#            dtype='int64', length=817)

# %%
df.sort_values('Age')
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 803          804         1       3       Thomas, Master. Assad Alexander
# 755          756         1       2             Hamalainen, Master. Viljo
# 644          645         1       3                Baclini, Miss. Eugenie
# 469          470         1       3         Baclini, Miss. Helene Barbara
# 831          832         1       2       Richards, Master. George Sibley
# ..           ...       ...     ...                                   ...
# 116          117         0       3                  Connors, Mr. Patrick
# 96            97         0       1             Goldschmidt, Mr. George B
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 851          852         0       3                   Svensson, Mr. Johan
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#      Gender    Age  SibSp  Parch    Ticket     Fare    Cabin Embarked
# ...

# %%
df.sort_index(axis=1)
# Out:
#            Age Cabin Embarked     Fare  Gender  \
# 0    22.000000   C85        S   7.2500    male
# 1    38.000000   C85        C  71.2833  female
# 2    26.000000  C123        S   7.9250  female
# 3    35.000000  C123        S  53.1000  female
# 4    35.000000   E46        S   8.0500    male
# ..         ...   ...      ...      ...     ...
# 886  27.000000   B42        S  13.0000    male
# 887  19.000000   B42        S  30.0000  female
# 888  29.699118  C148        S  23.4500  female
# 889  26.000000  C148        C  30.0000    male
# 890  32.000000  C148        Q   7.7500    male
#
#                                                   Name  Parch  PassengerId  \
# 0                              Braund, Mr. Owen Harris      0            1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                               Heikkinen, Miss. Laina      0            3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# ...

# %%
df['Age'].value_counts()
# Out:
# 29.699118    177
# 24.000000     30
# 22.000000     27
# 18.000000     26
# 28.000000     25
#             ...
# 36.500000      1
# 55.500000      1
# 0.920000       1
# 23.500000      1
# 74.000000      1
# Name: Age, Length: 89, dtype: int64

# %%
len(df['Age'].unique())
# Out:
# 89

# %%
df.Age.nunique()
# Out:
# 89

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   C85        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250  C123        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   E46        S

# %%
for category , dataframe in (df.groupby('Pclass')):
    print(category,dataframe)
# Out:
# 1      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name  Gender   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df.groupby('Pclass').first()
# Out:
#         PassengerId  Survived  \
# Pclass
# 1                 2         1
# 2                10         1
# 3                 1         0
#
#                                                      Name  Gender   Age  \
# Pclass
# 1       Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                     Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 3                                 Braund, Mr. Owen Harris    male  22.0
#
#         SibSp  Parch     Ticket     Fare Cabin Embarked
# Pclass
# 1           1      0   PC 17599  71.2833   C85        C
# 2           1      0     237736  30.0708    G6        C
# 3           1      0  A/5 21171   7.2500   C85        S

# %%
df_pclas3 = df.groupby('Pclass',sort=True).get_group(3)
df_pclas3
# Out:
#      PassengerId  Survived  Pclass         Name  Gender        Age  SibSp  \
# 0              1         0       3     [Braund]    male  22.000000      1
# 2              3         1       3  [Heikkinen]  female  26.000000      0
# 4              5         0       3      [Allen]    male  35.000000      0
# 5              6         0       3      [Moran]    male  29.699118      0
# 7              8         0       3    [Palsson]    male   2.000000      3
# ..           ...       ...     ...          ...     ...        ...    ...
# 882          883         0       3   [Dahlberg]  female  22.000000      0
# 884          885         0       3   [Sutehall]    male  25.000000      0
# 885          886         0       3       [Rice]  female  39.000000      0
# 888          889         0       3   [Johnston]  female  29.699118      1
# 890          891         0       3     [Dooley]    male  32.000000      0
#
#      Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.loc[df['Pclass']==2]
# Out:
#      PassengerId  Survived  Pclass  \
# 9             10         1       2
# 15            16         1       2
# 17            18         1       2
# 20            21         0       2
# 21            22         1       2
# ..           ...       ...     ...
# 866          867         1       2
# 874          875         1       2
# 880          881         1       2
# 883          884         0       2
# 886          887         0       2
#
#                                              Name  Gender        Age  SibSp  \
# 9             Nasser, Mrs. Nicholas (Adele Achem)  female  14.000000      1
# 15               Hewlett, Mrs. (Mary D Kingcome)   female  55.000000      0
# 17                   Williams, Mr. Charles Eugene    male  29.699118      0
# 20                           Fynney, Mr. Joseph J    male  35.000000      0
# 21                          Beesley, Mr. Lawrence    male  34.000000      0
# ..                                            ...     ...        ...    ...
# ...

# %%
df.loc[(df['Gender'] == 'male') & (df['Pclass'] == 1)]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 6              7         0       1               McCarthy, Mr. Timothy J
# 23            24         1       1          Sloper, Mr. William Thompson
# 27            28         0       1        Fortune, Mr. Charles Alexander
# 30            31         0       1              Uruchurtu, Don. Manuel E
# 34            35         0       1               Meyer, Mr. Edgar Joseph
# ..           ...       ...     ...                                   ...
# 839          840         1       1                  Marechal, Mr. Pierre
# 857          858         1       1                Daly, Mr. Peter Denis
# 867          868         0       1  Roebling, Mr. Washington Augustus II
# 872          873         0       1              Carlsson, Mr. Frans Olof
# 889          890         1       1                 Behr, Mr. Karl Howell
#
#     Gender        Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %%
df.loc[df['Gender']=='female']
# Out:
#      PassengerId  Survived  Pclass         Name  Gender        Age  SibSp  \
# 1              2         1       1    [Cumings]  female  38.000000      1
# 2              3         1       3  [Heikkinen]  female  26.000000      0
# 3              4         1       1   [Futrelle]  female  35.000000      1
# 8              9         1       3    [Johnson]  female  27.000000      0
# 9             10         1       2     [Nasser]  female  14.000000      1
# ..           ...       ...     ...          ...     ...        ...    ...
# 880          881         1       2    [Shelley]  female  25.000000      0
# 882          883         0       3   [Dahlberg]  female  22.000000      0
# 885          886         0       3       [Rice]  female  39.000000      0
# 887          888         1       1     [Graham]  female  19.000000      0
# 888          889         0       3   [Johnston]  female  29.699118      1
#
#      Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.groupby(['Pclass']).size()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# dtype: int64

# %%
df.groupby(['Pclass'])['Fare'].agg(np.sum)
# Out:
# Pclass
# 1    18177.4125
# 2     3801.8417
# 3     6714.6951
# Name: Fare, dtype: float64

# %%
df.groupby('Embarked').size()
# Out:
# Embarked
# C    168
# Q     77
# S    646
# dtype: int64

# %%
df.groupby('Embarked')['Fare'].agg(np.sum)
# Out:
# Embarked
# C    10072.2962
# Q     1022.2543
# S    17599.3988
# Name: Fare, dtype: float64

# %%
import re

# %%
df.Name.astype('str')
# Out:
# 0                           ['Braund', 'Owen', 'Harris']
# 1      ['Cumings', 'John', 'Bradley', 'Florence', 'Br...
# 2                         ['Heikkinen', 'Miss', 'Laina']
# 3       ['Futrelle', 'Jacques', 'Heath', 'Lily', 'Peel']
# 4                          ['Allen', 'William', 'Henry']
#                              ...
# 886                               ['Montvila', 'Juozas']
# 887              ['Graham', 'Miss', 'Margaret', 'Edith']
# 888    ['Johnston', 'Miss', 'Catherine', 'Helen', 'Ca...
# 889                           ['Behr', 'Karl', 'Howell']
# 890                                ['Dooley', 'Patrick']
# Name: Name, Length: 891, dtype: object

# %%
def fist_name(var):
    pattern = '\w{4,10}'
    return re.findall(pattern, str(var))

df['Name'] = df['Name'].apply(fist_name)
df['Name']
# Out:
# 0                                 [Braund, Owen, Harris]
# 1      [Cumings, John, Bradley, Florence, Briggs, Tha...
# 2                               [Heikkinen, Miss, Laina]
# 3                 [Futrelle, Jacques, Heath, Lily, Peel]
# 4                                [Allen, William, Henry]
#                              ...
# 886                                   [Montvila, Juozas]
# 887                      [Graham, Miss, Margaret, Edith]
# 888           [Johnston, Miss, Catherine, Helen, Carrie]
# 889                                 [Behr, Karl, Howell]
# 890                                    [Dooley, Patrick]
# Name: Name, Length: 891, dtype: object

# %%
def fist_name(var):
    
    return var[:1]

df['Name'] = df['Name'].apply(fist_name) 
df
# Out:
#      PassengerId  Survived  Pclass         Name  Gender        Age  SibSp  \
# 0              1         0       3     [Braund]    male  22.000000      1
# 1              2         1       1    [Cumings]  female  38.000000      1
# 2              3         1       3  [Heikkinen]  female  26.000000      0
# 3              4         1       1   [Futrelle]  female  35.000000      1
# 4              5         0       3      [Allen]    male  35.000000      0
# ..           ...       ...     ...          ...     ...        ...    ...
# 886          887         0       2   [Montvila]    male  27.000000      0
# 887          888         1       1     [Graham]  female  19.000000      0
# 888          889         0       3   [Johnston]  female  29.699118      1
# 889          890         1       1       [Behr]    male  26.000000      0
# 890          891         0       3     [Dooley]    male  32.000000      0
#
#      Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.groupby('Pclass',sort=True).mean('Age')
# Out:
#         PassengerId  Survived        Age     SibSp     Parch       Fare
# Pclass
# 1        461.597222  0.629630  37.048118  0.416667  0.356481  84.154687
# 2        445.956522  0.472826  29.866958  0.402174  0.380435  20.662183
# 3        439.154786  0.258656  26.403259  0.615071  0.393075  13.675550

# %%
df['Name'].isin([['Braund']]).sum()
# Out:
# 2

# %%
df.loc[~(df['Embarked']=='S')]
# Out:
#      PassengerId  Survived  Pclass          Name  Gender        Age  SibSp  \
# 1              2         1       1     [Cumings]  female  38.000000      1
# 5              6         0       3       [Moran]    male  29.699118      0
# 9             10         1       2      [Nasser]  female  14.000000      1
# 16            17         1       3        [Rice]    male   2.000000      4
# 19            20         1       3  [Masselmani]  female  29.699118      0
# ..           ...       ...     ...           ...     ...        ...    ...
# 875          876         1       3       [Najib]  female  15.000000      0
# 879          880         1       1      [Potter]  female  56.000000      0
# 885          886         0       3        [Rice]  female  39.000000      0
# 889          890         1       1        [Behr]    male  26.000000      0
# 890          891         0       3      [Dooley]    male  32.000000      0
#
#      Parch    Ticket     Fare Cabin Embarked
# ...
