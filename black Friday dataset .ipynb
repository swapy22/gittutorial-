# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %% [markdown]
# # Problem Statement
# A retail company “ABC Private Limited” wants to understand the customer purchase behaviour (specifically, purchase amount) against various products of different categories. They have shared purchase summary of various customers for selected high volume products from last month.
# The data set also contains customer demographics (age, gender, marital status, city_type, stay_in_current_city), product details (product_id and product category) and Total purchase_amount from last month.
#
# Now, they want to build a model to predict the purchase amount of customer against various products which will help them to create personalized offer for customers against different products.

# %%
df = pd.read_csv('blackfriday.csv')

# %%
df.head(5)
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000004  P00128942      M  46-50           7             B
# 1  1000009  P00113442      M  26-35          17             C
# 2  1000010  P00288442      F  36-45           1             B
# 3  1000010  P00145342      F  36-45           1             B
# 4  1000011  P00053842      F  26-35           1             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               1                   1
# 1                          0               0                   3
# 2                         4+               1                   5
# 3                         4+               1                   4
# 4                          1               0                   4
#
#    Product_Category_2  Product_Category_3
# 0                11.0                 NaN
# 1                 5.0                 NaN
# 2                14.0                 NaN
# 3                 9.0                 NaN
# 4                 5.0                12.0

# %%
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3'],
#       dtype='object')

# %%
df.shape
# Out:
# (233599, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 233599 entries, 0 to 233598
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     233599 non-null  int64
#  1   Product_ID                  233599 non-null  object
#  2   Gender                      233599 non-null  object
#  3   Age                         233599 non-null  object
#  4   Occupation                  233599 non-null  int64
#  5   City_Category               233599 non-null  object
#  6   Stay_In_Current_City_Years  233599 non-null  object
#  7   Marital_Status              233599 non-null  int64
#  8   Product_Category_1          233599 non-null  int64
#  9   Product_Category_2          161255 non-null  float64
#  10  Product_Category_3          71037 non-null   float64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 19.6+ MB

# %%
df.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  2.335990e+05  233599.000000   233599.000000       233599.000000
# mean   1.003029e+06       8.085407        0.410070            5.276542
# std    1.726505e+03       6.521146        0.491847            3.736380
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001527e+06       2.000000        0.000000            1.000000
# 50%    1.003070e+06       7.000000        0.000000            5.000000
# 75%    1.004477e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           18.000000
#
#        Product_Category_2  Product_Category_3
# count       161255.000000        71037.000000
# mean             9.849586           12.669454
# std              5.094943            4.125944
# min              2.000000            3.000000
# 25%              5.000000            9.000000
# 50%              9.000000           14.000000
# 75%             15.000000           16.000000
# max             18.000000           18.000000

# %%
df.drop(['User_ID'], axis=1,inplace=True)

# %%
df.head(2)
# Out:
#   Product_ID Gender    Age  Occupation City_Category  \
# 0  P00128942      M  46-50           7             B
# 1  P00113442      M  26-35          17             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               1                   1
# 1                          0               0                   3
#
#    Product_Category_2  Product_Category_3
# 0                11.0                 NaN
# 1                 5.0                 NaN

# %%
df['Gender'] = pd.get_dummies(df['Gender'],drop_first=1).head(10)

# %%
df.head(10)
# Out:
#   Product_ID  Gender    Age  Occupation City_Category  \
# 0  P00128942     1.0  46-50           7             B
# 1  P00113442     1.0  26-35          17             C
# 2  P00288442     0.0  36-45           1             B
# 3  P00145342     0.0  36-45           1             B
# 4  P00053842     0.0  26-35           1             C
# 5  P00350442     1.0  46-50           1             C
# 6  P00155442     1.0  46-50           1             C
# 7   P0094542     1.0  46-50           1             C
# 8  P00161842     1.0  26-35           7             A
# 9  P00067942     1.0  18-25          15             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               1                   1
# 1                          0               0                   3
# 2                         4+               1                   5
# 3                         4+               1                   4
# 4                          1               0                   4
# 5                          3               1                   2
# 6                          3               1                   1
# 7                          3               1                   2
# 8                          1               0                  10
# 9                         4+               0                   5
#
#    Product_Category_2  Product_Category_3
# 0                11.0                 NaN
# 1                 5.0                 NaN
# 2                14.0                 NaN
# 3                 9.0                 NaN
# 4                 5.0                12.0
# 5                 3.0                15.0
# 6                11.0                15.0
# 7                 4.0                 9.0
# 8                13.0                16.0
# 9                14.0                 NaN

# %%
# df['Gender'] = df['Gender'].map({'F': 0, 'M':1})

# %%
df.loc[10:]
# Out:
#        Product_ID  Gender    Age  Occupation City_Category  \
# 10      P00046742     NaN  26-35           7             B
# 11      P00040042     NaN  26-35           7             B
# 12      P00196542     NaN  26-35           7             B
# 13      P00004542     NaN  26-35           7             B
# 14      P00159542     NaN  26-35           1             C
# ...           ...     ...    ...         ...           ...
# 233594  P00118942     NaN  26-35          15             B
# 233595  P00254642     NaN  26-35          15             B
# 233596  P00031842     NaN  26-35          15             B
# 233597  P00124742     NaN  46-50           1             C
# 233598  P00316642     NaN  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 10                              2               1                   1
# 11                              2               1                   5
# 12                              2               1                   5
# 13                              2               1                   5
# 14                              2               1                  10
# ...                           ...             ...                 ...
# 233594                         4+               1                   8
# 233595                         4+               1                   5
# 233596                         4+               1                   1
# 233597                         4+               0                  10
# 233598                         4+               1                   4
#
#         Product_Category_2  Product_Category_3
# 10                     2.0                15.0
# 11                     NaN                 NaN
# 12                     8.0                14.0
# 13                     8.0                 NaN
# 14                    15.0                16.0
# ...                    ...                 ...
# 233594                 NaN                 NaN
# 233595                 8.0                 NaN
# 233596                 5.0                12.0
# 233597                16.0                 NaN
# 233598                 5.0                 NaN
#
# [233589 rows x 10 columns]

# %%
df.groupby("Gender").size()
# Out:
# Gender
# 0.0    3
# 1.0    7
# dtype: int64

# %%
df["Gender"].value_counts()
# Out:
# 1.0    7
# 0.0    3
# Name: Gender, dtype: int64

# %%
df.columns
# Out:
# Index(['Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3'],
#       dtype='object')

# %%
df.iloc[-1]
# Out:
# Product_ID                    P00316642
# Gender                              NaN
# Age                               46-50
# Occupation                            0
# City_Category                         B
# Stay_In_Current_City_Years           4+
# Marital_Status                        1
# Product_Category_1                    4
# Product_Category_2                  5.0
# Product_Category_3                  NaN
# Name: 233598, dtype: object

# %%
df['Age'].unique()
# Out:
# array([1, 2, 3, 4, 5, 6, 7], dtype=int64)

# %%
df['Age'] = df["Age"].map({'46-50':1, '26-35':2, '36-45':3, '18-25':4, '51-55':5, '55+':6, '0-17':7})

# %%
df.head(10)
# Out:
#   Product_ID  Gender  Age  Occupation City_Category  \
# 0  P00128942     NaN  NaN           7             B
# 1  P00113442     NaN  NaN          17             C
# 2  P00288442     NaN  NaN           1             B
# 3  P00145342     NaN  NaN           1             B
# 4  P00053842     NaN  NaN           1             C
# 5  P00350442     NaN  NaN           1             C
# 6  P00155442     NaN  NaN           1             C
# 7   P0094542     NaN  NaN           1             C
# 8  P00161842     NaN  NaN           7             A
# 9  P00067942     NaN  NaN          15             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               1                   1
# 1                          0               0                   3
# 2                         4+               1                   5
# 3                         4+               1                   4
# 4                          1               0                   4
# 5                          3               1                   2
# 6                          3               1                   1
# 7                          3               1                   2
# 8                          1               0                  10
# 9                         4+               0                   5
#
#    Product_Category_2  Product_Category_3
# 0                11.0                 NaN
# 1                 5.0                 NaN
# 2                14.0                 NaN
# 3                 9.0                 NaN
# 4                 5.0                12.0
# 5                 3.0                15.0
# 6                11.0                15.0
# 7                 4.0                 9.0
# 8                13.0                16.0
# 9                14.0                 NaN

# %%
df['City_Category'].unique()
# Out:
# array(['B', 'C', 'A'], dtype=object)
